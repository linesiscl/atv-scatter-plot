# %% [markdown]
# Aline Fernandes Zeppelini - rm97966
#
#
# Julia Leite Galvão - rm550201

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
df = pd.read_csv("/content/children_per_woman_total_fertility.csv")

# %%
x = df["country"][24:37]
y = df["2010"][24:37]

# %%
plt.figure(figsize=(20,10))
plt.scatter(x,y)
plt.xlabel('Países')
plt.ylabel('Número de crianças')
plt.title('Número de filhos por mulher, em cada país em 2010')
plt.show()
